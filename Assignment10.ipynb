# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamk16/Deep_learning/blob/master/Assignment10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/TSAI/
# Out:
# /content/gdrive/My Drive/TSAI

# %%
import albumentations # to apply image augmentation using albumentations library.
print(albumentations.__version__) # check verison

# this is to install and use albumentations latest package v0.4.5
album_version_needed = "0.4.5"
if albumentations.__version__ != album_version_needed:
  # !pip install -U git+https://github.com/albu/albumentations # --no-cache-dir
# Out:
# 0.4.5

# %%
from __future__ import print_function
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR, CyclicLR, ReduceLROnPlateau
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load standard packages

from __future__ import print_function
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR, CyclicLR, ReduceLROnPlateau

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pkgutil
import importlib

# install "apex" model for mixed precision training if required.. this is needed for LRFinder
if pkgutil.find_loader("apex") is None:
   print("apex module does not exist")
   # !pip install -U git+https://www.github.com/NVIDIA/apex --no-cache-dir

from utils.lr_finder import LRFinder # cutom module for LR finder
# Out:
# apex module does not exist
# Collecting git+https://www.github.com/NVIDIA/apex
#   Cloning https://www.github.com/NVIDIA/apex to /tmp/pip-req-build-t6upox29
#   Running command git clone -q https://www.github.com/NVIDIA/apex /tmp/pip-req-build-t6upox29
#   Running command git submodule update --init --recursive -q
# Building wheels for collected packages: apex
#   Building wheel for apex (setup.py) ... done
#   Created wheel for apex: filename=apex-0.1-cp36-none-any.whl size=153170 sha256=244b952f1467f37a17e3106d22c564abfac92080740798d35c2f01db31ab2a92
#   Stored in directory: /tmp/pip-ephem-wheel-cache-35dj8q4l/wheels/08/3e/36/a75a9914e497fe42598f9dbe67496b2b300a8851f4d396a285
# Successfully built apex
# Installing collected packages: apex
# Successfully installed apex-0.1

# %%
# load custom python packages
import utils.common_utils as cutils          # common utililies fxn
import utils.model_utils as mutils           # utilities for basic conv block, depthwise seperable blocks, train, test, build fucntions
import utils.model_history as model_history  # utilitie for storing and visualizing model results
from utils.plot_utils import PlotUtils       # utilities for ploting images, model history, misclassified images etc
#import models.cifar10_net_cnn as cifar10_net_cnn  # CIFAR10 network design using custom CNN network
import model.resnet as resnet                    # resnet model

import utils.albumentations as album_utils # utilities fxn based on albumentations
import gradcam.gradcam_abs as gradcamAbs

# %%
# check GPU availability and use cuda to get GPU device
cuda, device = cutils.get_device()
# Out:
# CUDA Available? True
# Device:  cuda:0

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

config_params = dict(
    seed=1,
    batch_size=128,
    num_workers=4,
    epochs=50
)

# For reproducibility
torch.manual_seed(config_params["seed"])

if cuda:
    torch.cuda.manual_seed(config_params["seed"])

# %%
means, stds = album_utils.calculate_dataset_mean_std()
print("means: {}".format(means))
print("stds: {}".format(stds))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# Total dataset(train+test) shape:  (60000, 32, 32, 3)
# means: [0.49186864, 0.48265335, 0.44717798]
# stds: [0.24697131, 0.24338901, 0.26159254]

# %%
# fill values for cutout portion
fill_value = [255. * mean for mean in means]

# to apply specific augmentation, set apply=True
# augmentaion is ignore is either apply=False or speific a attribute is missing
albumentations_args = dict(
            GeneralParams=dict(input_size=32),            
            RandomCrop=dict(apply=False, size=8, p=0.20),
            HorizontalFlip=dict(apply=True, p=0.7),
            ElasticTransform=dict(apply=False, sigma=50, alpha=1, alpha_affine=10, p=0.10),
            CoarseDropout=dict(apply=True, max_holes=1, max_height=16, max_width=16, min_height=4, min_width=4, fill_value=fill_value, p=0.70),
            Normalize=dict(apply=True, means=means, stds=stds))

albumentations_args
# Out:
# {'CoarseDropout': {'apply': True,
#   'fill_value': [125.42650446295738, 123.07660415768623, 114.03038397431374],
#   'max_height': 16,
#   'max_holes': 1,
#   'max_width': 16,
#   'min_height': 4,
#   'min_width': 4,
#   'p': 0.7},
#  'ElasticTransform': {'alpha': 1,
#   'alpha_affine': 10,
#   'apply': False,
#   'p': 0.1,
#   'sigma': 50},
#  'GeneralParams': {'input_size': 32},
#  'HorizontalFlip': {'apply': True, 'p': 0.7},
#  'Normalize': {'apply': True,
#   'means': [0.49186864, 0.48265335, 0.44717798],
#   'stds': [0.24697131, 0.24338901, 0.26159254]},
#  'RandomCrop': {'apply': False, 'p': 0.2, 'size': 8}}

# %%
train_transforms, test_transforms = album_utils.get_data_transform(albumentations_args)
# Out:
# CoarseDropout/Cutout is enabled
# HorizontalFlip is enabled

# %%
# load data
train_loader, test_loader = album_utils.get_dataloader(train_transforms, test_transforms, 
                                                       batch_size=config_params["batch_size"], num_workers=config_params["num_workers"])
# Out:
# CUDA Available? True
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# create PlotUtils class instance
putils = PlotUtils(device, classes, means, stds)

# %%
# visualize how image aumentation is applied on few training dataset images: 
putils.plot_dataset_images(train_loader, save_filename="albumentations_images")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-24a274b41a32> in <module>()
# ----> 1 putils.plot_dataset_images(train_loader, save_filename="albumentations_images")
#
# /content/gdrive/My Drive/TSAI/utils/plot_utils.py in plot_dataset_images(self, data_loader, num_of_images, save_filename)
#     145                         if(cnt==num_of_images):
#     146                                 break
# --> 147                 fig.savefig("./images/{}.png".format(save_filename))
#     148                 return
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2103                     orientation=orientation,
#    2104                     bbox_inches_restore=_bbox_inches_restore,
# -> 2105                     **kwargs)
#    2106             finally:
#    2107                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/albumentations_images.png'

# %%
# Create CIFAR10 network
model = resnet.ResNet18()
mutils.model_summary(model, device, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#            Dropout-5           [-1, 64, 32, 32]               0
#             Conv2d-6           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-7           [-1, 64, 32, 32]             128
#         BasicBlock-8           [-1, 64, 32, 32]               0
#             Conv2d-9           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-10           [-1, 64, 32, 32]             128
#           Dropout-11           [-1, 64, 32, 32]               0
#            Conv2d-12           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-13           [-1, 64, 32, 32]             128
#        BasicBlock-14           [-1, 64, 32, 32]               0
#            Conv2d-15          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#           Dropout-17          [-1, 128, 16, 16]               0
#            Conv2d-18          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-19          [-1, 128, 16, 16]             256
#            Conv2d-20          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#        BasicBlock-22          [-1, 128, 16, 16]               0
#            Conv2d-23          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-24          [-1, 128, 16, 16]             256
#           Dropout-25          [-1, 128, 16, 16]               0
#            Conv2d-26          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-27          [-1, 128, 16, 16]             256
#        BasicBlock-28          [-1, 128, 16, 16]               0
#            Conv2d-29            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#           Dropout-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-38            [-1, 256, 8, 8]             512
#           Dropout-39            [-1, 256, 8, 8]               0
#            Conv2d-40            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-41            [-1, 256, 8, 8]             512
#        BasicBlock-42            [-1, 256, 8, 8]               0
#            Conv2d-43            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-44            [-1, 512, 4, 4]           1,024
#           Dropout-45            [-1, 512, 4, 4]               0
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#            Conv2d-48            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-49            [-1, 512, 4, 4]           1,024
#        BasicBlock-50            [-1, 512, 4, 4]               0
#            Conv2d-51            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-52            [-1, 512, 4, 4]           1,024
#           Dropout-53            [-1, 512, 4, 4]               0
#            Conv2d-54            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-55            [-1, 512, 4, 4]           1,024
#        BasicBlock-56            [-1, 512, 4, 4]               0
#            Linear-57                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 13.13
# Params size (MB): 42.63
# Estimated Total Size (MB): 55.76
# ----------------------------------------------------------------

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-7, momentum=0.9, weight_decay=1e-3)
lr_finder = LRFinder(model, optimizer, criterion, device=device)
lr_finder.range_test(train_loader, end_lr=100, num_iter=200, step_mode="exp")
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
# Note that the loss in the loss vs. learning rate plot is the training loss.
lr_finder.plot()

# %%
# To restore the model and optimizer to their initial state
lr_finder.reset()
'''
Here model is evaluated on that validation dataset after each iteration.
The evaluation loss is more sensitive to instability therefore it provides a more precise view of when the divergence occurs. 
The disadvantage is that it takes significantly longer to run
'''
lr_finder.range_test(train_loader, val_loader=test_loader, end_lr=100, num_iter=150, step_mode="exp")
# Out:
# HBox(children=(IntProgress(value=0, max=150), HTML(value='')))
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
# Note that the loss in the loss vs. learning rate plot is the validation loss.
lr_finder.plot()

# %%
model_name = "CIFAR10 Resnet18"
model =  model.to(device)
EPOCHS = config_params["epochs"]

start_lr = 1e-4 # minimum LR as per LRFinder result
end_lr = 5e-2   # maximu LR as per LRFinder result
step_size = 6   # stepsize for Lr cycle policy

#criterion = F.nll_loss()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=0.001)  # using L2 Regulaization

# CyclicLR-Triangular policy
lr_scheduler = CyclicLR(optimizer, base_lr=start_lr, max_lr=end_lr, step_size_up=step_size, mode='triangular2')
#lr_scheduler = MultiStepLR(optimizer, milestones=[8,16,24], gamma=0.3)
#lr_scheduler = StepLR(optimizer, step_size=8, gamma=0.1)

# reduce LR when modle get stuck in plateu region
reduceLr_scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4, threshold=0.001)

model_history = mutils.build_model(model, 
                            device, 
                            trainloader=train_loader, 
                            testloader=test_loader, 
                            epochs=EPOCHS,
                            criterion=criterion, 
                            optimizer=optimizer,
                            lr_scheduler=lr_scheduler,
                            reduceLr_scheduler=reduceLr_scheduler,
                            L1_loss_enable=True)
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH-1: learning rate is: 0.0001
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Loss=2.318709 Batch_id=391 Accuracy=32.55: 100%|██████████| 391/391 [01:05<00:00,  6.00it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.700174, Accuracy: 3722/10000 (37.22%)
#
# EPOCH-2: learning rate is: 0.008416666666666659
# Loss=1.785922 Batch_id=391 Accuracy=50.11: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.108084, Accuracy: 6047/10000 (60.47%)
#
# EPOCH-3: learning rate is: 0.01673333333333334
# Loss=1.447962 Batch_id=391 Accuracy=62.52: 100%|██████████| 391/391 [01:04<00:00,  6.07it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.065294, Accuracy: 6383/10000 (63.83%)
#
# EPOCH-4: learning rate is: 0.02505
# Loss=1.229661 Batch_id=391 Accuracy=70.03: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.770068, Accuracy: 7370/10000 (73.70%)
#
# EPOCH-5: learning rate is: 0.03336666666666666
# Loss=1.078221 Batch_id=391 Accuracy=74.59: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.848671, Accuracy: 7227/10000 (72.27%)
#
# EPOCH-6: learning rate is: 0.04168333333333334
# Loss=0.976335 Batch_id=391 Accuracy=77.31: 100%|██████████| 391/391 [01:04<00:00,  6.06it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.625579, Accuracy: 7955/10000 (79.55%)
#
# EPOCH-7: learning rate is: 0.05
# Loss=0.888883 Batch_id=391 Accuracy=79.59: 100%|██████████| 391/391 [01:04<00:00,  6.04it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.626477, Accuracy: 7885/10000 (78.85%)
#
# EPOCH-8: learning rate is: 0.04168333333333332
# Loss=0.789828 Batch_id=391 Accuracy=82.19: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.535209, Accuracy: 8218/10000 (82.18%)
#
# EPOCH-9: learning rate is: 0.03336666666666668
# Loss=0.709139 Batch_id=391 Accuracy=84.12: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.466685, Accuracy: 8421/10000 (84.21%)
#
# EPOCH-10: learning rate is: 0.02505
# Loss=0.640184 Batch_id=391 Accuracy=86.15: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.474998, Accuracy: 8423/10000 (84.23%)
#
# EPOCH-11: learning rate is: 0.01673333333333332
# Loss=0.565751 Batch_id=391 Accuracy=88.32: 100%|██████████| 391/391 [01:04<00:00,  6.06it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.423435, Accuracy: 8557/10000 (85.57%)
#
# EPOCH-12: learning rate is: 0.008416666666666682
# Loss=0.489465 Batch_id=391 Accuracy=90.64: 100%|██████████| 391/391 [01:04<00:00,  6.06it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.373658, Accuracy: 8778/10000 (87.78%)
#
# EPOCH-13: learning rate is: 0.0001
# Loss=0.432619 Batch_id=391 Accuracy=92.71: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.330363, Accuracy: 8881/10000 (88.81%)
#
# EPOCH-14: learning rate is: 0.004258333333333319
# Loss=0.421095 Batch_id=391 Accuracy=93.04: 100%|██████████| 391/391 [01:04<00:00,  6.04it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.337258, Accuracy: 8869/10000 (88.69%)
#
# EPOCH-15: learning rate is: 0.008416666666666682
# Loss=0.440767 Batch_id=391 Accuracy=91.94: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.412379, Accuracy: 8663/10000 (86.63%)
#
# EPOCH-16: learning rate is: 0.012575
# Loss=0.474364 Batch_id=391 Accuracy=90.60: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.402671, Accuracy: 8668/10000 (86.68%)
#
# EPOCH-17: learning rate is: 0.01673333333333332
# Loss=0.506603 Batch_id=391 Accuracy=89.21: 100%|██████████| 391/391 [01:04<00:00,  6.04it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.490983, Accuracy: 8406/10000 (84.06%)
#
# EPOCH-18: learning rate is: 0.02089166666666668
# Loss=0.528914 Batch_id=391 Accuracy=88.39: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.440559, Accuracy: 8538/10000 (85.38%)
#
# EPOCH-19: learning rate is: 0.0025050000000000003
# Loss=0.397646 Batch_id=391 Accuracy=93.29: 100%|██████████| 391/391 [01:04<00:00,  6.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.305608, Accuracy: 8971/10000 (89.71%)
#
# EPOCH-20: learning rate is: 0.02089166666666668
# Loss=0.496240 Batch_id=391 Accuracy=89.41: 100%|██████████| 391/391 [01:04<00:00,  6.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.454640, Accuracy: 8489/10000 (84.89%)
#
# EPOCH-21: learning rate is: 0.01673333333333332
# Loss=0.462355 Batch_id=391 Accuracy=90.60: 100%|██████████| 391/391 [01:05<00:00,  6.01it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.385828, Accuracy: 8708/10000 (87.08%)
#
# EPOCH-22: learning rate is: 0.012575
# Loss=0.410435 Batch_id=391 Accuracy=92.36: 100%|██████████| 391/391 [01:05<00:00,  6.01it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.397540, Accuracy: 8702/10000 (87.02%)
#
# EPOCH-23: learning rate is: 0.008416666666666682
# Loss=0.354728 Batch_id=391 Accuracy=94.18: 100%|██████████| 391/391 [01:05<00:00,  6.01it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.354443, Accuracy: 8847/10000 (88.47%)
#
# EPOCH-24: learning rate is: 0.004258333333333319
# Loss=0.304082 Batch_id=391 Accuracy=95.83: 100%|██████████| 391/391 [01:04<00:00,  6.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.295686, Accuracy: 9028/10000 (90.28%)
#
# EPOCH-25: learning rate is: 0.0001
# Loss=0.277859 Batch_id=391 Accuracy=96.69: 100%|██████████| 391/391 [01:04<00:00,  6.04it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.282945, Accuracy: 9083/10000 (90.83%)
#
# EPOCH-26: learning rate is: 0.0021791666666666704
# Loss=0.274250 Batch_id=391 Accuracy=96.92: 100%|██████████| 391/391 [01:04<00:00,  6.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.276506, Accuracy: 9072/10000 (90.72%)
#
# EPOCH-27: learning rate is: 0.00425833333333333
# Loss=0.274499 Batch_id=391 Accuracy=96.69: 100%|██████████| 391/391 [01:04<00:00,  6.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.318703, Accuracy: 8975/10000 (89.75%)
#
# EPOCH-28: learning rate is: 0.0063375
# Loss=0.294880 Batch_id=391 Accuracy=95.74: 100%|██████████| 391/391 [01:04<00:00,  6.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.341612, Accuracy: 8928/10000 (89.28%)
#
# EPOCH-29: learning rate is: 0.00841666666666667
# Loss=0.325491 Batch_id=391 Accuracy=94.58: 100%|██████████| 391/391 [01:04<00:00,  6.04it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.412118, Accuracy: 8772/10000 (87.72%)
#
# EPOCH-30: learning rate is: 0.01049583333333333
# Loss=0.356043 Batch_id=391 Accuracy=93.49: 100%|██████████| 391/391 [01:04<00:00,  6.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.434438, Accuracy: 8651/10000 (86.51%)
#
# EPOCH-31: learning rate is: 0.012575
# Loss=0.391418 Batch_id=391 Accuracy=92.29: 100%|██████████| 391/391 [01:05<00:00,  6.01it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.411171, Accuracy: 8672/10000 (86.72%)
#
# EPOCH-32: learning rate is: 0.001049583333333333
# Loss=0.299822 Batch_id=391 Accuracy=95.86: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.283784, Accuracy: 9055/10000 (90.55%)
#
# EPOCH-33: learning rate is: 0.00841666666666667
# Loss=0.316255 Batch_id=391 Accuracy=94.97: 100%|██████████| 391/391 [01:04<00:00,  6.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.366639, Accuracy: 8820/10000 (88.20%)
#
# EPOCH-34: learning rate is: 0.0063375
# Loss=0.283850 Batch_id=391 Accuracy=96.06: 100%|██████████| 391/391 [01:04<00:00,  6.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.339648, Accuracy: 8928/10000 (89.28%)
#
# EPOCH-35: learning rate is: 0.00425833333333333
# Loss=0.255993 Batch_id=391 Accuracy=96.94: 100%|██████████| 391/391 [01:04<00:00,  6.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.300082, Accuracy: 9059/10000 (90.59%)
#
# EPOCH-36: learning rate is: 0.0021791666666666704
# Loss=0.226295 Batch_id=391 Accuracy=97.95: 100%|██████████| 391/391 [01:04<00:00,  6.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.279407, Accuracy: 9137/10000 (91.37%)
#
# EPOCH-37: learning rate is: 1e-05
# Loss=0.216992 Batch_id=391 Accuracy=98.26: 100%|██████████| 391/391 [01:04<00:00,  6.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.282960, Accuracy: 9119/10000 (91.19%)
#
# EPOCH-38: learning rate is: 0.0011395833333333407
# Loss=0.213872 Batch_id=391 Accuracy=98.38: 100%|██████████| 391/391 [01:04<00:00,  6.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.275269, Accuracy: 9154/10000 (91.54%)
#
# EPOCH-39: learning rate is: 0.002179166666666659
# Loss=0.210675 Batch_id=391 Accuracy=98.39: 100%|██████████| 391/391 [01:04<00:00,  6.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.297112, Accuracy: 9088/10000 (90.88%)
#
# EPOCH-40: learning rate is: 0.00321875
# Loss=0.215552 Batch_id=391 Accuracy=98.13: 100%|██████████| 391/391 [01:04<00:00,  6.04it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.292239, Accuracy: 9088/10000 (90.88%)
#
# EPOCH-41: learning rate is: 0.004258333333333341
# Loss=0.223199 Batch_id=391 Accuracy=97.69: 100%|██████████| 391/391 [01:04<00:00,  6.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.316840, Accuracy: 9008/10000 (90.08%)
#
# EPOCH-42: learning rate is: 0.005297916666666659
# Loss=0.238497 Batch_id=391 Accuracy=97.19: 100%|██████████| 391/391 [01:04<00:00,  6.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.327886, Accuracy: 9023/10000 (90.23%)
#
# EPOCH-43: learning rate is: 0.0063375
# Loss=0.264877 Batch_id=391 Accuracy=96.11: 100%|██████████| 391/391 [01:05<00:00,  6.01it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.381389, Accuracy: 8876/10000 (88.76%)
#
# EPOCH-44: learning rate is: 0.0005297916666666659
# Loss=0.224019 Batch_id=391 Accuracy=97.68: 100%|██████████| 391/391 [01:04<00:00,  6.04it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.285746, Accuracy: 9128/10000 (91.28%)
#
# EPOCH-45: learning rate is: 0.004258333333333341
# Loss=0.227965 Batch_id=391 Accuracy=97.45: 100%|██████████| 391/391 [01:05<00:00,  6.01it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.318256, Accuracy: 9008/10000 (90.08%)
#
# EPOCH-46: learning rate is: 0.00321875
# Loss=0.211665 Batch_id=391 Accuracy=97.88: 100%|██████████| 391/391 [01:05<00:00,  6.00it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.303111, Accuracy: 9054/10000 (90.54%)
#
# EPOCH-47: learning rate is: 0.002179166666666659
# Loss=0.195769 Batch_id=391 Accuracy=98.42: 100%|██████████| 391/391 [01:05<00:00,  6.01it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.291572, Accuracy: 9128/10000 (91.28%)
#
# EPOCH-48: learning rate is: 0.0011395833333333407
# Loss=0.182809 Batch_id=391 Accuracy=98.84: 100%|██████████| 391/391 [01:04<00:00,  6.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.278804, Accuracy: 9144/10000 (91.44%)
#
# EPOCH-49: learning rate is: 1e-05
# Loss=0.177635 Batch_id=391 Accuracy=98.94: 100%|██████████| 391/391 [01:04<00:00,  6.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.279544, Accuracy: 9137/10000 (91.37%)
#
# EPOCH-50: learning rate is: 0.0006197916666666649
# Loss=0.177393 Batch_id=391 Accuracy=99.01: 100%|██████████| 391/391 [01:04<00:00,  6.05it/s]
# Test set: Average loss: 0.278756, Accuracy: 9163/10000 (91.63%)

# %%
# model result summary
model_history.result_summary()
# Out:
# Training best result: Accuracy: 99.01 at Epoch 50
# Testing  best result: Accuracy: 91.63 at Epoch 50
# Acuracy Gap: 7.38

# %%
# get class based test accuracy for the network
mutils.class_based_accuracy(model, device, classes, test_loader)
# Out:
# Accuracy of plane : 100 %
# Accuracy of   car : 97 %
# Accuracy of  bird : 90 %
# Accuracy of   cat : 77 %
# Accuracy of  deer : 87 %
# Accuracy of   dog : 93 %
# Accuracy of  frog : 92 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 91 %

# %%
# Accurracy and loss history plot
model_history.plot_history(title=model_name)#, save_filename="model_history")
# Out:
# /content/gdrive/My Drive/TSAI/utils/model_history.py:110: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1,x_size+1),x_size/10)
# /content/gdrive/My Drive/TSAI/utils/model_history.py:121: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1,x_size+1),x_size/10)

# %%
# Note: seriesname="val_acc", "val_loss", "train_acc", "train_loss", "lr"
model_history.plot_data_against_epoch("LR values", seriesname="lr")
# Out:
# /content/gdrive/My Drive/TSAI/utils/model_history.py:68: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs.set_xticks(np.arange(1,x_size+1),x_size/10)

# %%
print("\nPloting misclassified images: {}\n".format(model_name))
putils.plot_misclassified_images(model, testloader=test_loader)#,save_filename="model_misclassified")
# Out:
# Ploting misclassified images: CIFAR10 Resnet18
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-0ac9ace5059b> in <module>()
#       1 print("\nPloting misclassified images: {}\n".format(model_name))
# ----> 2 putils.plot_misclassified_images(model, testloader=test_loader)#,save_filename="model_misclassified")
#
# /content/gdrive/My Drive/TSAI/utils/plot_utils.py in plot_misclassified_images(self, model, testloader, num_of_images, save_filename)
#     122                           break
#     123
# --> 124                 fig.savefig("./images/{}.png".format(save_filename))
#     125                 return
#     126
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2103                     orientation=orientation,
#    2104                     bbox_inches_restore=_bbox_inches_restore,
# -> 2105                     **kwargs)
#    2106             finally:
#    2107                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/misclassified.png'

# %%
# create instance of GradCam module
config = dict(model_type='resnet', arch=model, layer_name='layer4')
gcam = gradcamAbs.GradCamAbs(device, config, means, stds)

# %%
gradcam_images, pred_results = gcam.applyOnMisclassifiedImages(dataloader=test_loader, num_of_images=25)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2416: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
gcam.plot_results(gradcam_images, pred_results, classes, save_filename="gradcam_result_details")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-f47c98b3fed2> in <module>()
# ----> 1 gcam.plot_results(gradcam_images, pred_results, classes, save_filename="gradcam_result_details")
#
# /content/gdrive/My Drive/TSAI/gradcam/gradcam_abs.py in plot_results(self, images_set, predictions, classesname, save_filename)
#     124               cnt += 1
#     125
# --> 126           fig.savefig("./images/{}.png".format(save_filename))
#     127           return
#     128
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2103                     orientation=orientation,
#    2104                     bbox_inches_restore=_bbox_inches_restore,
# -> 2105                     **kwargs)
#    2106             finally:
#    2107                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/gradcam_result_details.png'
